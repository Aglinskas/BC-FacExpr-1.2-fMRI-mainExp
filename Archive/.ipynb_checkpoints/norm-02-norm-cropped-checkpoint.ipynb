# %%
pwd
# Out:
# '/Users/aidasaglinskas/Desktop/BC-FacExpr-1.2-fMRI-mainExp'

# %%
from matplotlib import pyplot as plt
from PIL import Image, ImageEnhance,ImageStat
import skvideo
import skvideo.io
import numpy as np
import os
from tqdm import tqdm

# %%
def load_video(fn):
    videodata = skvideo.io.vread(fn)
    return videodata

# %%
files = [os.path.join('./stimuli_cropped/',file) for file in os.listdir('./stimuli_cropped/') if file.endswith('.mp4')]
files.sort()
files[0:5]
# Out:
# ['./stimuli_cropped/ID1_d1_1.mp4',
#  './stimuli_cropped/ID1_d1_2.mp4',
#  './stimuli_cropped/ID1_d1_3.mp4',
#  './stimuli_cropped/ID1_d1_4.mp4',
#  './stimuli_cropped/ID1_f_1.mp4']

# %%
len(files)
# Out:
# 145

# %%
hist_brightness = []
hist_contrast = []
hist_r = []
hist_g = []
hist_b = []
for file in tqdm(files):
    vid = load_video(file)
    hist_brightness.append(  vid[0,:,:,:].mean()  )
    hist_contrast.append(  vid[0,:,:,:].mean(axis=-1).std() )
    
    hist_r.append( vid[:,:,:,0].mean() )
    hist_g.append( vid[:,:,:,1].mean() )
    hist_b.append( vid[:,:,:,2].mean() )
# Out:
# 100%|█████████████████████████████████████████| 145/145 [00:22<00:00,  6.31it/s]

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,3,1)
plt.hist(hist_brightness);
plt.title('brightness');
plt.subplot(1,3,2)
plt.hist(hist_contrast);
plt.title('contrast');
plt.subplot(1,3,3)
plt.hist(hist_r,color='r',alpha=.5);
plt.hist(hist_g,color='g',alpha=.5);
plt.hist(hist_b,color='b',alpha=.5);
plt.title('rgb hist');

# %%
brightness_target = np.array(hist_brightness).mean()
brightness_target.round(3)
# Out:
# 81.817

# %%
contrast_target = np.array(hist_contrast).mean()
contrast_target.round(3)
# Out:
# 53.689

# %%
target_r = np.array(hist_r).mean().round(3)
target_g = np.array(hist_g).mean().round(3)
target_b = np.array(hist_b).mean().round(3)
(target_r,target_g,target_b)
# Out:
# (85.944, 76.293, 83.229)

# %%
def brighten_video(videodata,factor=1):
    return np.array([np.array(ImageEnhance.Brightness(Image.fromarray(videodata[frame,:,:,:])).enhance(factor)) for frame in range(videodata.shape[0])])

# %%
def contrast_video(videodata,factor=1):
    return np.array([np.array(ImageEnhance.Contrast(Image.fromarray(videodata[frame,:,:,:])).enhance(factor)) for frame in range(videodata.shape[0])])

# %%
def save_video(videodata,ofn='outvideo.mp4'):
    skvideo.io.vwrite(ofn, videodata.astype(np.uint8),outputdict={'-codec': 'h264', '-filter:v' : 'fps=29.97'})

# %%
def tint_video(videodata,ctargets,bw=False): 
    #ctargets = (target_r,target_g,target_b)
    videodata_copy = videodata.copy()
    videodata_copy = videodata_copy.astype(np.float) # otherwie 255 overflows and you get patches
    for channel in range(3):
        for frame in range(videodata.shape[0]):
            if bw==False:
                c_diff = ctargets[channel]-videodata[frame,:,:,channel].mean()
                videodata_copy[frame,:,:,channel] = videodata_copy[frame,:,:,channel]+c_diff
                videodata_copy[videodata_copy>255]=255
                
            else:
                bw_frame = np.array(Image.fromarray(videodata_copy[frame,:,:,:]).convert('L'))
                videodata_copy[frame,:,:,channel] = bw_frame
            
    return videodata_copy

# %%
def tint_video(videodata,ctargets): 
    #ctargets = (target_r,target_g,target_b)
    videodata_copy = videodata.copy()
    for frame in range(videodata.shape[0]):
        for channel in range(3):
            c_diff = ctargets[channel]-videodata[frame,:,:,channel].mean() # 
            videodata_copy[frame,:,:,channel] = videodata_copy[frame,:,:,channel]+c_diff
            videodata_copy[videodata_copy>255]=255
    return videodata_copy

# %%
f = 30
fn = files[f]
videodata = load_video(fn)
ctargets = (target_r,target_g,target_b)
videodata_copy = videodata.copy()
videodata_copy = videodata_copy.astype(np.float)
for frame in range(videodata.shape[0]):
    for channel in range(3):
        c_diff = ctargets[channel]-videodata[frame,:,:,channel].mean() # 
        videodata_copy[frame,:,:,channel] = videodata_copy[frame,:,:,channel]+c_diff
        videodata_copy[videodata_copy>255]=255
        
videodata_copy = videodata_copy.astype(np.uint8)
#tinted_video = tint_video(videodata,(target_r,target_g,target_b))
# Out:
# /var/folders/vq/3kk0fzh5509g0jkz5rt3zzsh0000gn/T/ipykernel_42532/1622630659.py:6: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   videodata_copy = videodata_copy.astype(np.float)

# %%
#Image.fromarray(videodata_copy[0,:,:,:])

# %%
#Image.fromarray(videodata[0,:,:,:])

# %%
f = 30
fn = files[f]
videodata = load_video(fn)
tint_values = np.array([videodata[0,:,:,i].mean().round(2) for i in range(3)])
print(f'tint values {tint_values}')
print(f'tint target {(target_r,target_g,target_b)}')
for i in range(25):
    videodata = tint_video(videodata,(target_r,target_g,target_b))
    tint_values = np.array([videodata[0,:,:,i].mean().round(2) for i in range(3)])
print(f'tint values {tint_values}')

# %%
def resize_video(video_data,vid_size_target=(512,512)):
    from PIL import Image, ImageEnhance,ImageStat
    import numpy as np
    
    #vid_size_target = np.array((512,512))
    vid_size_target = np.array(vid_size_target)
    vid_size = np.array((video_data.shape[1],video_data.shape[2]))
    nframes = video_data.shape[0]
    nchannels = video_data.shape[-1]
    video_data_new = np.zeros((nframes,vid_size_target[0],vid_size_target[1],nchannels))
    for f in range(nframes):
        video_data_new[f,:,:,:] = np.array(Image.fromarray(video_data[f,:,:,:]).resize(vid_size_target,Image.ANTIALIAS))

    return video_data_new

# %%
# NORMALIZE TO TARGET VALUES
#for f in tqdm(range(len(files))):
for f in tqdm(  np.arange(0,145,15)  ):
    fn = files[f]
    videodata = load_video(fn)
    for i in range(25):
            contrast = videodata[0,:,:,:].mean(axis=-1).std()
            brightness = videodata[0,:,:,:].mean()
            videodata = contrast_video(videodata,contrast_target/contrast)
            videodata = brighten_video(videodata,brightness_target/brightness)
            videodata = tint_video(videodata,(target_r,target_g,target_b),bw=False)
    save_video(videodata,ofn=fn.replace('./stimuli_cropped/','./stimuli_cropped_normed/'))
# Out:
# 100%|███████████████████████████████████████████| 10/10 [01:47<00:00, 10.75s/it]

# %%
f = 30
fn = files[f]
videodata = load_video(fn)
tint_values = np.array([videodata[0,:,:,i].mean().round(2) for i in range(3)])
print(f'tint values {tint_values}')
print(f'tint target {(target_r,target_g,target_b)}')
for i in range(25):
    videodata = tint_video(videodata,(target_r,target_g,target_b))
    tint_values = np.array([videodata[0,:,:,i].mean().round(2) for i in range(3)])
print(f'tint values {tint_values}')
# Out:
# tint values [90.04 68.08 67.55]
# tint target (86.006, 76.384, 83.061)
# tint values [85.04 75.63 83.04]

# %%
f = 30
fn = files[f]
videodata = load_video(fn)
tint_values = np.array([videodata[0,:,:,i].mean().round(2) for i in range(3)])
print(f'tint values {tint_values}')
print(f'tint target {(target_r,target_g,target_b)}')
for i in range(20):
    #videodata = tint_video(videodata,(target_r,target_g,target_b))
    videodata = tint_video(videodata,(125,125,125))
    tint_values = np.array([videodata[0,:,:,i].mean().round(2) for i in range(3)])
print(f'tint values {tint_values}')
# Out:
# tint values [90.04 68.08 67.55]
# tint target (86.007, 76.384, 83.06)
# tint values [124.39 124.74 124.98]

# %%
from skimage.exposure import match_histograms

# %%
f = 30
fn = files[f]
videodata = load_video(fn)
frame1 = videodata[0,:,:,:]

# %%
f = 0
fn = files[f]
videodata = load_video(fn)
frame2 = videodata[0,:,:,:]

# %%
Image.fromarray(frame1)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x1779463D0>

# %%
Image.fromarray(frame2)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x16C67F610>

# %%
Image.fromarray(match_histograms(frame1,frame2,channel_axis=2).astype(np.uint8))
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x1679D41F0>

# %%
mean_frame = [resize_video(load_video(file)).mean(axis=0) for file in tqdm(files)]
mean_frame = np.array(mean_frame).mean(axis=0).astype(np.uint8)
plt.imsave('mean_frame.png',arr=mean_frame)
# Out:
# 100%|█████████████████████████████████████████| 145/145 [00:45<00:00,  3.21it/s]

# %%
Image.fromarray(match_histograms(frame1,mean_frame,channel_axis=2).astype(np.uint8))
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x16877C070>

# %%
files = [os.path.join('./stimuli_cropped_normed/',file) for file in os.listdir('./stimuli_cropped_normed/') if file.endswith('.mp4')]
files.sort()
files[0:5]

hist_brightness = []
hist_contrast = []

hist_r = []
hist_g = []
hist_b = []


for file in tqdm(files):
    vid = load_video(file)
    hist_brightness.append(  vid[0,:,:,:].mean()  )
    hist_contrast.append(  vid[0,:,:,:].mean(axis=-1).std() )
            
    hist_r.append( vid[0,:,:,0].mean() )
    hist_g.append( vid[0,:,:,1].mean() )
    hist_b.append( vid[0,:,:,2].mean() )

    
plt.figure(figsize=(15,5))
plt.subplot(1,3,1)
plt.hist(hist_brightness);
plt.title('brightness');
plt.subplot(1,3,2)
plt.hist(hist_contrast);
plt.title('contrast');
plt.subplot(1,3,3)
plt.hist(hist_r,color='r',alpha=.5);
plt.hist(hist_g,color='g',alpha=.5);
plt.hist(hist_b,color='b',alpha=.5);
plt.title('rgb hist');
# Out:
# 100%|███████████████████████████████████████████| 10/10 [00:01<00:00,  6.65it/s]

# %%
np.array(hist_brightness).mean().round(3)
# Out:
# 125.516

# %%
np.array(hist_contrast).mean().round(3)
# Out:
# 28.657

# %%
[np.array(i).mean().round(3) for i in [hist_r,hist_g,hist_b]]
# Out:
# [124.844, 131.399, 120.307]
