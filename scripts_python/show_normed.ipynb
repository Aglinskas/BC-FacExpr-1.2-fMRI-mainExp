# %%
from matplotlib import pyplot as plt
import os

from matplotlib import pyplot as plt
from PIL import Image, ImageEnhance,ImageStat
import skvideo
import skvideo.io
import numpy as np
import os
from tqdm import tqdm
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
files = [file for file in os.listdir('./stimuli') if file.endswith('.mp4')]

# %%
def load_video(fn):
    #fn = 'ID4_h1_1.mp4'
    videodata = skvideo.io.vread(fn)
    return videodata

# %%
files = [
'ID1_d1_2.mp4',
'ID2_d2_3.mp4',
'ID3_d1_3.mp4',
'ID4_d1_4.mp4',
'ID5_h1_3.mp4']

for file in files:
    plt.figure(figsize=np.array((15,5))*1.5)
    plt.subplot(1,2,1)
    plt.imshow(load_video(os.path.join('./stimuli',file))[0,:,:,:]);plt.xticks([]);plt.yticks([]);
    plt.subplot(1,2,2)
    plt.imshow(load_video(os.path.join('./stimuli_normed',file))[0,:,:,:]);plt.xticks([]);plt.yticks([]);
